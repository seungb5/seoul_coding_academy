# %%
# !pip install savReaderWriter
# Out:
# ...
#   Stored in directory: C:\Users\tmznq\AppData\Local\pip\Cache\wheels\cc\c5\c2\25171e344dff66668d68736623515b77ecda30dc399270c9ed
# Successfully built savReaderWriter
# ...

# %%
import pandas as pd 
import numpy as np
import savReaderWriter as spss 
import matplotlib.pyplot as plt
import mglearn
plt.rc('figure', figsize=(12, 6))

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
from sklearn.preprocessing import normalize

# %% [markdown]
# ## 실습문제 04
# ![](https://tensorflowkorea.files.wordpress.com/2017/06/2-13.png?w=768)
# - 위 그림은 보스턴 주택가격 데이터셋에 대한 릿지 회귀와 선형 회귀의 학습 곡선이다.

# %%
mglearn.plots.plot_ridge_n_samples()

# %% [markdown]
# #### 1. 이 학습곡선에 대해 normalize선형 회귀의 학습 곡선이다. 이 학습곡선에 대해 normalize=True를 주었을 때, Ridge와 LASSO의 학습곡선을 그려라.

# %%
# 함수 호출하기

# %%
# %load -n mglearn.plots.plot_ridge_n_samples
def plot_ridge_n_samples():
    X, y = load_extended_boston()

    plot_learning_curve(Ridge(alpha=1), X, y)
    plot_learning_curve(LinearRegression(), X, y)
    plt.legend(loc=(0, 1.05), ncol=2, fontsize=11)

# %%
from mglearn import plots
from mglearn import plot_ridge

# %%
# %load -n mglearn.plot_ridge
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import Ridge, LinearRegression
from sklearn.model_selection import learning_curve, KFold

from mglearn.datasets import load_extended_boston


def plot_learning_curve(est, X, y):
    training_set_size, train_scores, test_scores = learning_curve(
        est, X, y, train_sizes=np.linspace(.1, 1, 20), cv=KFold(20, shuffle=True, random_state=1))
    estimator_name = est.__class__.__name__
    line = plt.plot(training_set_size, train_scores.mean(axis=1), '--',
                    label="training " + estimator_name)
    plt.plot(training_set_size, test_scores.mean(axis=1), '-',
             label="test " + estimator_name, c=line[0].get_color())
    plt.xlabel('Training set size')
    plt.ylabel('Score (R^2)')
    plt.ylim(0, 1.1)


def plot_ridge_n_samples():
    X, y = load_extended_boston()

    plot_learning_curve(Ridge(alpha=1), X, y)
    plot_learning_curve(Lasso(), X, y)
    plt.legend(loc=(0, 1.05), ncol=2, fontsize=11)
    
mglearn.plots.plot_ridge_n_samples()

# %%
# 2. 이 학습곡선에 cancer 데이터에 대해 LogisticReg, LinearSVC를 그려라.

# %%
# load_extended_boston()

# %%
load_breast_cancer()['data']
# load_breast_cancer()['target']
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.datasets import load_breast_cancer

def plot_2():
    X, y = load_breast_cancer()['data'], load_breast_cancer()['target']

    plot_learning_curve(LogisticRegression(C=100), X, y)
    plot_learning_curve(LinearSVC(C=1), X, y)
    plt.legend(loc=(0, 1.05), ncol=2, fontsize=11)

# %%
plt.plot(plot_2())
# Out:
# C:\Users\tmznq\Anaconda3\envs\ml_scratch\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tmznq\Anaconda3\envs\ml_scratch\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tmznq\Anaconda3\envs\ml_scratch\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tmznq\Anaconda3\envs\ml_scratch\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
