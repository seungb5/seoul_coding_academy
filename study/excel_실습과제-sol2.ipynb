# %%
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# 'C:\\Users\\tmznq\\workspace\\ml_scratch\\seoul_coding_academy\\study'

# %%
# !dir # !: 윈도우 명령입력. 즉, 명령프롬프트(cmd)랑 같은 상태임. 근데 왜 폴더 이동 안되냐... ㅠ ㅠ
# Out:
# 지정된 경로를 찾을 수 없습니다.

# %%
# error : Install xlrd >= 1.0.0 for Excel support 이거 깔으랍니다.
# !pip install xlrd

# %%
path = 'C:/Users/tmznq/workspace/ml_scratch/seoul_coding_academy/강의자료/excel_exam.xlsx'
data = pd.read_excel(path)
data.head()
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60
# 2   3      1    45       86       78
# 3   4      1    30       98       58
# 4   5      2    25       80       65

# %% [markdown]
# #### 문제 정의
# - 반별 과목별 평균을 구하고, 반별 평균보다 높은 학생 id를 출력하라.

# %%
# class와 id에 따른 pivoting
df = data.pivot_table(index=['class', 'id'])
df.head()
# Out:
#           english  math  science
# class id
# 1     1        98    50       50
#       2        97    60       60
#       3        86    45       78
#       4        98    30       58
# 2     5        80    25       65

# %%
# 학생의 과목별 평균 구하기.
df2 = np.mean(df, axis = 0)
df2
# Out:
# english    84.90
# math       57.45
# science    59.45
# dtype: float64

# %%
# 반 별 grouping
df2 = df.groupby(level = 0, group_keys=False) # group_keys....?
df2

# %%
for i in df2:
    print(i)
# Out:
# (1,           english  math  science
# class id
# 1     1        98    50       50
#       2        97    60       60
#       3        86    45       78
#       4        98    30       58)
# (2,           english  math  science
# class id
# 2     5        80    25       65
#       6        89    50       98
#       7        90    80       45
#       8        78    90       25)
# (3,           english  math  science
# class id
# 3     9        98    20       15
#       10       98    50       45
#       11       65    65       65
#       12       85    45       32)
# (4,           english  math  science
# class id
# 4     13       98    46       65
#       14       87    48       12
#       15       56    75       78
#       16       98    58       65)
# (5,           english  math  science
# class id
# 5     17       68    65       98
#       18       78    80       90
#       19       68    89       87
#       20       83    78       58)

# %%
df.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d3a028362a04> in <module>()
# ----> 1 df.fillna()
#
# ~\Anaconda3\envs\ml_scratch\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    4032                      self).fillna(value=value, method=method, axis=axis,
#    4033                                   inplace=inplace, limit=limit,
# -> 4034                                   downcast=downcast, **kwargs)
#    4035
#    4036     @Appender(_shared_docs['replace'] % _shared_doc_kwargs)
#
# ~\Anaconda3\envs\ml_scratch\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6042         """
#    6043         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 6044         value, method = validate_fillna_kwargs(value, method)
#    6045
#    6046         self._consolidate_inplace()
#
# ~\Anaconda3\envs\ml_scratch\lib\site-packages\pandas\util\_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     344
#     345     if value is None and method is None:
# --> 346         raise ValueError("Must specify a fill 'value' or 'method'.")
#     347     elif value is None and method is not None:
#     348         method = clean_fill_method(method)
#
# ValueError: Must specify a fill 'value' or 'method'.

# %%
df2.mean()
# Out:
#        english   math  science
# class
# 1        94.75  46.25    61.50
# 2        84.25  61.25    58.25
# 3        86.50  45.00    39.25
# 4        84.75  56.75    55.00
# 5        74.25  78.00    83.25

# %%
result = pd.DataFrame(df2.apply(lambda x: x[x > x.mean()]).fillna(value = '미달')) # x[x > x.mean()] : fancy indexing
result
# Out:
#          english math science
# class id
# 1     1       98   50      미달
#       2       97   60      미달
#       3       미달   미달      78
#       4       98   미달      미달
# 2     5       미달   미달      65
#       6       89   미달      98
#       7       90   80      미달
#       8       미달   90      미달
# 3     9       98   미달      미달
#       10      98   50      45
#       11      미달   65      65
#       12      미달   미달      미달
# 4     13      98   미달      65
#       14      87   미달      미달
#       15      미달   75      78
#       16      98   58      65
# 5     17      미달   미달      98
#       18      78   80      90
#       19      미달   89      87
#       20      83   미달      미달

# %%
result[['english']].dropna()
# Out:
#          english
# class id
# 1     1       98
#       2       97
#       3       미달
#       4       98
# 2     5       미달
#       6       89
#       7       90
#       8       미달
# 3     9       98
#       10      98
#       11      미달
#       12      미달
# 4     13      98
#       14      87
#       15      미달
#       16      98
# 5     17      미달
#       18      78
#       19      미달
#       20      83

# %%
# solution
path = 'C:/Users/tmznq/workspace/ml_scratch/seoul_coding_academy/강의자료/excel_exam.xlsx'

def id(path, subject = ''):
    data = pd.read_excel(path) # excel 불러오기
    df = data.pivot_table(index=['class', 'id']) # data pivot
    df2 = df.groupby(level = 0, group_keys=False) # groupby
    result = pd.DataFrame(df2.apply(lambda x: x[x > x.mean()])) # apply에 함수 적용
    
    return result[['{}'.format(subject)]].dropna()

# %%
path = 'C:/Users/tmznq/workspace/ml_scratch/seoul_coding_academy/강의자료/excel_exam.xlsx'

def all(path):
    data = pd.read_excel(path) # excel 불러오기
    df = data.pivot_table(index=['class', 'id']) # data pivot
    df2 = df.groupby(level = 0, group_keys=False) # groupby
    result = pd.DataFrame(df2.apply(lambda x: x[x > x.mean()]).fillna(value = '평균이하'))
    return result

# %%
id(path, subject = 'english').head()
# Out:
#           english
# class id
# 1     1      98.0
#       2      97.0
#       4      98.0
# 2     6      89.0
#       7      90.0

# %%
all(path)
# Out:
#          english  math science
# class id
# 1     1       98    50    평균이하
#       2       97    60    평균이하
#       3     평균이하  평균이하      78
#       4       98  평균이하    평균이하
# 2     5     평균이하  평균이하      65
#       6       89  평균이하      98
#       7       90    80    평균이하
#       8     평균이하    90    평균이하
# 3     9       98  평균이하    평균이하
#       10      98    50      45
#       11    평균이하    65      65
#       12    평균이하  평균이하    평균이하
# 4     13      98  평균이하      65
#       14      87  평균이하    평균이하
#       15    평균이하    75      78
#       16      98    58      65
# 5     17    평균이하  평균이하      98
#       18      78    80      90
#       19    평균이하    89      87
#       20      83  평균이하    평균이하

# %% [markdown]
# ___

# %%
# cf) class별 평균으로 정렬해보기.
result2 = pd.DataFrame(df2.apply(lambda x: x.sort_values(ascending=False)))
result2.head()
# Out:
#                mean
# class id
# 1     2   72.333333
#       3   69.666667
#       1   66.000000
#       4   62.000000
# 2     6   79.000000
